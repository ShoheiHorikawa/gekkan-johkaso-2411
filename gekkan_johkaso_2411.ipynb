# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoheiHorikawa/gekkan-johkaso-2411/blob/main/gekkan_johkaso_2411.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 573.2 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 13.9 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

if __name__ == '__main__':
    # Load a model
    model = YOLO('yolov8n.pt')

    # Predict the model
    model.predict('https://ultralytics.com/images/bus.jpg', save=True, conf=0.5)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 73.8MB/s]
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100%|██████████| 134k/134k [00:00<00:00, 5.80MB/s]
# image 1/1 /content/bus.jpg: 640x480 3 persons, 1 bus, 482.1ms
# Speed: 19.5ms preprocess, 482.1ms inference, 35.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/predict/bus.jpg')
